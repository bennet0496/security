# %%
import math
import sys
import urllib3
import io
import ipaddress
import certifi
from packaging import version
import datetime

# %%
RIR_TABLES = {
    "APNIC":   "https://ftp.apnic.net/stats/apnic/delegated-apnic-extended-latest",
    "AFRINIC": "https://ftp.afrinic.net/stats/afrinic/delegated-afrinic-extended-latest",
    "ARIN":    "https://ftp.arin.net/pub/stats/arin/delegated-arin-extended-latest",
    "LACNIC":  "https://ftp.lacnic.net/pub/stats/lacnic/delegated-lacnic-extended-latest",
    "RIPE":    "https://ftp.ripe.net/ripe/stats/delegated-ripencc-extended-latest"
}
for rir in RIR_TABLES:
    print(rir)
# Out:
# APNIC
# AFRINIC
# ARIN
# LACNIC
# RIPE

# %%
CACHE = {
    "APNIC": [],
    "AFRINIC": [],
    "ARIN": [],
    "LACNIC": [],
    "RIPE": []
}
for rir in RIR_TABLES:
    print("# Downloading RIR from {}".format(rir))
    http = urllib3.PoolManager(
        cert_reqs='CERT_REQUIRED',
        ca_certs=certifi.where()
    )
    r = http.request('GET', RIR_TABLES[rir], preload_content=False)
    if version.parse(urllib3.__version__) < version.parse("1.25"):
        class ExplicitlyClosedHttpResponse(urllib3.HTTPResponse):
            @property
            def closed(self):
                return self._fp.closed
        # change the class from standard urllib3.HttpResponse
        r.__class__ = ExplicitlyClosedHttpResponse
    else:
        r.auto_close = False

    rir_raw = [line.strip('\n').split("|") for line in io.TextIOWrapper(r) if not line.startswith("#")]
    rir_header = rir_raw[:4]
    rir_list = rir_raw[4:]

    del rir_raw

    rversion,registry,serial,records,startdate,enddate,_  = rir_header[0]
    
    try:
        startdate = datetime.datetime.strptime(startdate, '%Y%m%d').strftime('%a %b %d %Y')
    except ValueError:
        startdate = "N/A"
    try:
        enddate = datetime.datetime.strptime(enddate, '%Y%m%d').strftime('%a %b %d %Y')
    except ValueError:
        enddate = "N/A"

    num = {
        rir_header[1][2]: rir_header[1][4],
        rir_header[2][2]: rir_header[2][4],
        rir_header[3][2]: rir_header[3][4]
    }
    print("# Got {}/{} v{} allocations from {}".format(len(rir_list), records, rversion, str(registry).upper()))
    print("# {} - {}".format(startdate, enddate))
    print("# {}:{} {}:{} {}:{}".format(rir_header[1][2], rir_header[1][4],rir_header[2][2], rir_header[2][4], rir_header[3][2], rir_header[3][4]))
    CACHE[rir] = rir_list
# Out:
# # Downloading RIR from APNIC
# # Got 162328/162328 v2.3 allocations from APNIC
# # N/A - Sun Feb 12 2023
# # asn:12456 ipv4:52861 ipv6:97011
# # Downloading RIR from AFRINIC
# # Got 14928/14928 v2 allocations from AFRINIC
# # N/A - Mon Feb 13 2023
# # asn:3326 ipv4:5069 ipv6:6533
# # Downloading RIR from ARIN
# # Got 175769/175769 v2.3 allocations from ARIN
# # Thu Jan 01 1970 - Sun Feb 12 2023
# # asn:30840 ipv4:73276 ipv6:71653
# # Downloading RIR from LACNIC
# # Got 85852/85852 v2.3 allocations from LACNIC
# # Thu Jan 01 1987 - Fri Feb 10 2023
# # ipv4:19609 ipv6:52179 asn:14064
# # Downloading RIR from RIPE
# # Got 239610/239610 v2 allocations from RIPENCC
# # Tue Jul 05 1983 - Sun Feb 12 2023
# # ipv4:91136 asn:42541 ipv6:105933

# %%
CACHE
# Out:
# {'APNIC': [['apnic',
#    'AU',
#    'ipv4',
#    '1.0.0.0',
#    '256',
#    '20110811',
#    'assigned',
#    'A91872ED'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.0.1.0',
#    '256',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.0.2.0',
#    '512',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.0.4.0',
#    '1024',
#    '20110412',
#    'allocated',
#    'A9192210'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.0.8.0',
#    '2048',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.0.16.0',
#    '4096',
#    '20110412',
#    'allocated',
#    'A92D9378'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.0.32.0',
#    '8192',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.0.64.0',
#    '16384',
#    '20110412',
#    'allocated',
#    'A9252414'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '1.0.128.0',
#    '32768',
#    '20110408',
#    'allocated',
#    'A91CF4FE'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.1.0.0',
#    '256',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.1.1.0',
#    '256',
#    '20110811',
#    'assigned',
#    'A91872ED'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.1.2.0',
#    '512',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.1.4.0',
#    '1024',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.1.8.0',
#    '256',
#    '20110412',
#    'allocated',
#    'A9143FA7'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.1.9.0',
#    '256',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.1.10.0',
#    '512',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.1.12.0',
#    '1024',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.1.16.0',
#    '4096',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.1.32.0',
#    '8192',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.1.64.0',
#    '16384',
#    '20110412',
#    'allocated',
#    'A92D9378'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '1.1.128.0',
#    '32768',
#    '20110408',
#    'allocated',
#    'A91CF4FE'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.0.0',
#    '512',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.2.0',
#    '256',
#    '20110331',
#    'assigned',
#    'A9272682'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.2.3.0',
#    '256',
#    '20110811',
#    'assigned',
#    'A9173591'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.4.0',
#    '256',
#    '20110414',
#    'allocated',
#    'A9299C10'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.5.0',
#    '256',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.6.0',
#    '512',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.8.0',
#    '256',
#    '20110412',
#    'assigned',
#    'A92501F1'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.9.0',
#    '256',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.10.0',
#    '512',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.12.0',
#    '1024',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.16.0',
#    '4096',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.32.0',
#    '8192',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.2.64.0',
#    '16384',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '1.2.128.0',
#    '32768',
#    '20110408',
#    'allocated',
#    'A91CF4FE'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.3.0.0',
#    '65536',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.4.0.0',
#    '256',
#    '20110811',
#    'assigned',
#    'A9173591'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.4.1.0',
#    '256',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.4.2.0',
#    '512',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.4.4.0',
#    '256',
#    '20110331',
#    'assigned',
#    'A9272682'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.4.5.0',
#    '256',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.4.6.0',
#    '512',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.4.8.0',
#    '2048',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.4.16.0',
#    '4096',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.4.32.0',
#    '8192',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.4.64.0',
#    '16384',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '1.4.128.0',
#    '32768',
#    '20110408',
#    'allocated',
#    'A91CF4FE'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.5.0.0',
#    '65536',
#    '20110401',
#    'allocated',
#    'A9262674'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '1.6.0.0',
#    '131072',
#    '20110331',
#    'allocated',
#    'A92C99E2'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.8.0.0',
#    '65536',
#    '20110404',
#    'allocated',
#    'A9258BD1'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '1.9.0.0',
#    '65536',
#    '20100610',
#    'allocated',
#    'A91BDE77'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.10.0.0',
#    '2048',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.10.8.0',
#    '512',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '1.10.10.0',
#    '256',
#    '20210804',
#    'assigned',
#    'A922CF81'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.10.11.0',
#    '256',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.10.12.0',
#    '1024',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.10.16.0',
#    '4096',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.10.32.0',
#    '8192',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.10.64.0',
#    '16384',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '1.10.128.0',
#    '32768',
#    '20110408',
#    'allocated',
#    'A91CF4FE'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '1.11.0.0',
#    '65536',
#    '20100616',
#    'allocated',
#    'A922C04D'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.12.0.0',
#    '262144',
#    '20100511',
#    'allocated',
#    'A926DD6D'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '1.16.0.0',
#    '262144',
#    '20100512',
#    'allocated',
#    'A9222B0E'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '1.20.0.0',
#    '65536',
#    '20110404',
#    'allocated',
#    'A9129C87'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.21.0.0',
#    '16384',
#    '20100616',
#    'allocated',
#    'A92D3CAE'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.21.64.0',
#    '8192',
#    '20100616',
#    'allocated',
#    'A92D3CAE'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.21.96.0',
#    '4096',
#    '20100616',
#    'allocated',
#    'A92D5187'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.21.112.0',
#    '4096',
#    '20100616',
#    'allocated',
#    'A92D3CAE'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.21.128.0',
#    '4096',
#    '20100616',
#    'allocated',
#    'A92D5187'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.21.144.0',
#    '4096',
#    '20100616',
#    'allocated',
#    'A92D3CAE'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.21.160.0',
#    '8192',
#    '20100616',
#    'allocated',
#    'A92D3CAE'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.21.192.0',
#    '16384',
#    '20100616',
#    'allocated',
#    'A92D3CAE'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '1.22.0.0',
#    '131072',
#    '20100505',
#    'allocated',
#    'A924BDFC'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.24.0.0',
#    '524288',
#    '20100505',
#    'allocated',
#    'A924128D'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '1.32.0.0',
#    '32768',
#    '20110405',
#    'allocated',
#    'A91D55F5'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '1.32.128.0',
#    '16384',
#    '20110405',
#    'allocated',
#    'A91676D4'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '1.32.192.0',
#    '16384',
#    '20110405',
#    'allocated',
#    'A918C661'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.33.0.0',
#    '65536',
#    '20100628',
#    'allocated',
#    'A92D890B'],
#   ['apnic',
#    'TW',
#    'ipv4',
#    '1.34.0.0',
#    '131072',
#    '20100505',
#    'allocated',
#    'A92FA433'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '1.36.0.0',
#    '65536',
#    '20100629',
#    'allocated',
#    'A918495F'],
#   ['apnic',
#    'PH',
#    'ipv4',
#    '1.37.0.0',
#    '65536',
#    '20110405',
#    'allocated',
#    'A9146207'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '1.38.0.0',
#    '131072',
#    '20100526',
#    'allocated',
#    'A9118F4C'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.40.0.0',
#    '262144',
#    '20100524',
#    'allocated',
#    'A915A300'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.44.0.0',
#    '65536',
#    '20100524',
#    'allocated',
#    'A91514B1'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.45.0.0',
#    '65536',
#    '20100706',
#    'allocated',
#    'A924AA12'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '1.46.0.0',
#    '131072',
#    '20100526',
#    'allocated',
#    'A91D1136'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.48.0.0',
#    '131072',
#    '20100528',
#    'allocated',
#    'A92709DA'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.50.0.0',
#    '65536',
#    '20100902',
#    'allocated',
#    'A92F152F'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.51.0.0',
#    '65536',
#    '20100712',
#    'allocated',
#    'A9288AE2'],
#   ['apnic',
#    'VN',
#    'ipv4',
#    '1.52.0.0',
#    '262144',
#    '20100526',
#    'allocated',
#    'A9271131'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.56.0.0',
#    '524288',
#    '20100528',
#    'allocated',
#    'A92817F4'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '1.64.0.0',
#    '131072',
#    '20100629',
#    'allocated',
#    'A918495F'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.66.0.0',
#    '131072',
#    '20100701',
#    'allocated',
#    'A92EDD1C'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.68.0.0',
#    '262144',
#    '20100701',
#    'allocated',
#    'A926B78D'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.72.0.0',
#    '524288',
#    '20100701',
#    'allocated',
#    'A92EDD1C'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.80.0.0',
#    '524288',
#    '20100805',
#    'allocated',
#    'A92BD93E'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.88.0.0',
#    '262144',
#    '20100805',
#    'allocated',
#    'A925F123'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.92.0.0',
#    '131072',
#    '20100805',
#    'allocated',
#    'A9273844'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.94.0.0',
#    '131072',
#    '20100806',
#    'allocated',
#    'A92C9C95'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '1.96.0.0',
#    '1048576',
#    '20100607',
#    'allocated',
#    'A92DDC30'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '1.112.0.0',
#    '262144',
#    '20100602',
#    'allocated',
#    'A9153AE1'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.116.0.0',
#    '131072',
#    '20100611',
#    'allocated',
#    'A92AAFEB'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.118.0.0',
#    '65536',
#    '20100611',
#    'allocated',
#    'A923F31D'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.119.0.0',
#    '32768',
#    '20100611',
#    'allocated',
#    'A921E1FD'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.119.128.0',
#    '32768',
#    '20100611',
#    'allocated',
#    'A923C833'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.120.0.0',
#    '524288',
#    '20100518',
#    'allocated',
#    'A916A983'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.128.0.0',
#    '2097152',
#    '20100518',
#    'allocated',
#    'A916A983'],
#   ['apnic',
#    'TW',
#    'ipv4',
#    '1.160.0.0',
#    '1048576',
#    '20100505',
#    'allocated',
#    'A92FA433'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '1.176.0.0',
#    '131072',
#    '20100616',
#    'allocated',
#    'A922C04D'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.178.0.0',
#    '8192',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '1.178.32.0',
#    '8192',
#    '20100625',
#    'allocated',
#    'A917E678'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.178.64.0',
#    '8192',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.178.96.0',
#    '4096',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.178.144.0',
#    '4096',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.178.160.0',
#    '8192',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.178.192.0',
#    '4096',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '1.178.208.0',
#    '4096',
#    '20100625',
#    'allocated',
#    'A912F535'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.179.0.0',
#    '8192',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.179.32.0',
#    '2048',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.179.48.0',
#    '4096',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.179.64.0',
#    '2048',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.179.80.0',
#    '2048',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '1.179.96.0',
#    '4096',
#    '20100625',
#    'allocated',
#    'A91DB4FE'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '1.179.128.0',
#    '32768',
#    '20110408',
#    'allocated',
#    'A91CF4FE'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.180.0.0',
#    '262144',
#    '20100628',
#    'allocated',
#    'A92BCDA1'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.184.0.0',
#    '131072',
#    '20100604',
#    'allocated',
#    'A92751C6'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '1.186.0.0',
#    '65536',
#    '20100713',
#    'allocated',
#    'A922AB0D'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '1.187.0.0',
#    '65536',
#    '20110406',
#    'allocated',
#    'A929E0AE'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.188.0.0',
#    '262144',
#    '20100528',
#    'allocated',
#    'A92817F4'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.192.0.0',
#    '524288',
#    '20100619',
#    'allocated',
#    'A922724D'],
#   ['apnic',
#    'TW',
#    'ipv4',
#    '1.200.0.0',
#    '65536',
#    '20110407',
#    'allocated',
#    'A929275D'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '1.201.0.0',
#    '65536',
#    '20100713',
#    'allocated',
#    'A927D9D0'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.202.0.0',
#    '131072',
#    '20100609',
#    'allocated',
#    'A92BADD3'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '1.204.0.0',
#    '262144',
#    '20100528',
#    'allocated',
#    'A92709DA'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '1.208.0.0',
#    '1048576',
#    '20100611',
#    'allocated',
#    'A921B13E'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '1.224.0.0',
#    '2097152',
#    '20100719',
#    'allocated',
#    'A92860B7'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '2.57.124.0',
#    '1024',
#    '20190319',
#    'allocated',
#    'A9125475'],
#   ['apnic',
#    'PH',
#    'ipv4',
#    '2.58.228.0',
#    '1024',
#    '20190322',
#    'allocated',
#    'A91ADE0A'],
#   ['apnic',
#    'KH',
#    'ipv4',
#    '5.28.32.0',
#    '2048',
#    '20120508',
#    'allocated',
#    'A914F5BA'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '5.254.128.0',
#    '8192',
#    '20120914',
#    'allocated',
#    'A91D0F17'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '8.128.0.0',
#    '4194304',
#    '19921201',
#    'allocated',
#    'A91EA198'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '8.208.0.0',
#    '1048576',
#    '19921201',
#    'allocated',
#    'A91EA198'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.0.0.0',
#    '2048',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.0.8.0',
#    '1024',
#    '20100910',
#    'allocated',
#    'A92653C3'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.0.12.0',
#    '1024',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'VN',
#    'ipv4',
#    '14.0.16.0',
#    '4096',
#    '20100914',
#    'allocated',
#    'A9234159'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.0.32.0',
#    '8192',
#    '20100912',
#    'allocated',
#    'A9287A3E'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.0.64.0',
#    '16384',
#    '20100912',
#    'allocated',
#    'A9287A3E'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.0.128.0',
#    '32768',
#    '20100909',
#    'allocated',
#    'A916AAFF'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.1.0.0',
#    '1024',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.1.4.0',
#    '1024',
#    '20100910',
#    'allocated',
#    'A921903A'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.1.8.0',
#    '2048',
#    '20100910',
#    'allocated',
#    'A92FFC6E'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '14.1.16.0',
#    '1024',
#    '20100916',
#    'allocated',
#    'A919B63C'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.1.20.0',
#    '1024',
#    '20100920',
#    'allocated',
#    'A9150D5C'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.1.24.0',
#    '1024',
#    '20151214',
#    'allocated',
#    'A9273844'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '14.1.28.0',
#    '1024',
#    '20151215',
#    'allocated',
#    'A91B19CD'],
#   ['apnic',
#    'NZ',
#    'ipv4',
#    '14.1.32.0',
#    '8192',
#    '20100913',
#    'allocated',
#    'A916C128'],
#   ['apnic',
#    'US',
#    'ipv4',
#    '14.1.64.0',
#    '8192',
#    '20100914',
#    'allocated',
#    'A91758DF'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.1.96.0',
#    '1024',
#    '20160112',
#    'assigned',
#    'A9194F8F'],
#   ['apnic',
#    'BD',
#    'ipv4',
#    '14.1.100.0',
#    '1024',
#    '20160112',
#    'allocated',
#    'A91871C2'],
#   ['apnic',
#    'PK',
#    'ipv4',
#    '14.1.104.0',
#    '1024',
#    '20160112',
#    'allocated',
#    'A9150F66'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.1.108.0',
#    '1024',
#    '20160112',
#    'allocated',
#    'A92C26B8'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '14.1.112.0',
#    '1024',
#    '20160112',
#    'allocated',
#    'A91EA198'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.1.116.0',
#    '1024',
#    '20160112',
#    'assigned',
#    'A921E8BC'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.1.120.0',
#    '1024',
#    '20160112',
#    'assigned',
#    'A923E990'],
#   ['apnic',
#    'MN',
#    'ipv4',
#    '14.1.124.0',
#    '1024',
#    '20160112',
#    'allocated',
#    'A914DA2D'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.1.128.0',
#    '32768',
#    '20100910',
#    'allocated',
#    'A9117394'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '14.2.0.0',
#    '65536',
#    '20100813',
#    'allocated',
#    'A912B0A3'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.3.0.0',
#    '65536',
#    '20110119',
#    'allocated',
#    'A924F76D'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.4.0.0',
#    '262144',
#    '20100824',
#    'allocated',
#    'A92676CE'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.8.0.0',
#    '524288',
#    '20100817',
#    'allocated',
#    'A92D830B'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.16.0.0',
#    '1048576',
#    '20100906',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.32.0.0',
#    '2097152',
#    '20100802',
#    'allocated',
#    'A92DDC30'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.64.0.0',
#    '2097152',
#    '20100802',
#    'allocated',
#    'A92DDC30'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.96.0.0',
#    '131072',
#    '20100831',
#    'allocated',
#    'A917DEA4'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.98.0.0',
#    '65536',
#    '20100831',
#    'allocated',
#    'A912BE9D'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.99.0.0',
#    '65536',
#    '20100831',
#    'allocated',
#    'A917DEA4'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '14.100.0.0',
#    '32768',
#    '20100816',
#    'allocated',
#    'A915F89C'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '14.100.128.0',
#    '32768',
#    '20100816',
#    'allocated',
#    'A91AA48F'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.101.0.0',
#    '65536',
#    '20100817',
#    'allocated',
#    'A92D830B'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.102.0.0',
#    '32768',
#    '20100913',
#    'allocated',
#    'A925E8CC'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.102.128.0',
#    '1024',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.102.132.0',
#    '1024',
#    '20100914',
#    'allocated',
#    'A923C220'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '14.102.136.0',
#    '2048',
#    '20100913',
#    'allocated',
#    'A91B268A'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.102.144.0',
#    '2048',
#    '20100917',
#    'allocated',
#    'A91D1691'],
#   ['apnic',
#    'ID',
#    'ipv4',
#    '14.102.152.0',
#    '1024',
#    '20100921',
#    'allocated',
#    'A92179B5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.102.156.0',
#    '1024',
#    '20100924',
#    'allocated',
#    'A91B9D4B'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.102.160.0',
#    '1024',
#    '20160112',
#    'assigned',
#    'A92B1682'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.102.164.0',
#    '1024',
#    '20160113',
#    'allocated',
#    'A91F002A'],
#   ['apnic',
#    'PH',
#    'ipv4',
#    '14.102.168.0',
#    '1024',
#    '20160113',
#    'allocated',
#    'A91560A3'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '14.102.176.0',
#    '1024',
#    '20160113',
#    'allocated',
#    'A917C9BF'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.102.180.0',
#    '1024',
#    '20160113',
#    'allocated',
#    'A92B3287'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.102.184.0',
#    '1024',
#    '20160113',
#    'allocated',
#    'A9191D04'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.102.188.0',
#    '1024',
#    '20160113',
#    'assigned',
#    'A92B69D7'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.102.192.0',
#    '8192',
#    '20100920',
#    'allocated',
#    'A92CE503'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.102.240.0',
#    '4096',
#    '20100921',
#    'allocated',
#    'A91A4132'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.103.0.0',
#    '65536',
#    '20100810',
#    'allocated',
#    'A92FEB6F'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.104.0.0',
#    '524288',
#    '20100818',
#    'allocated',
#    'A92530DA'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.112.0.0',
#    '1048576',
#    '20100906',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.128.0.0',
#    '1024',
#    '20101206',
#    'allocated',
#    'A923DECA'],
#   ['apnic',
#    'NZ',
#    'ipv4',
#    '14.128.4.0',
#    '1024',
#    '20100914',
#    'allocated',
#    'A913D7D6'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '14.128.8.0',
#    '256',
#    '20100915',
#    'allocated',
#    'A91A46B0'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '14.128.9.0',
#    '256',
#    '20100915',
#    'allocated',
#    'A9142B64'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '14.128.10.0',
#    '512',
#    '20100915',
#    'allocated',
#    'A9142B64'],
#   ['apnic',
#    'BD',
#    'ipv4',
#    '14.128.12.0',
#    '1024',
#    '20180808',
#    'allocated',
#    'A91EC9A5'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.128.16.0',
#    '4096',
#    '20100920',
#    'allocated',
#    'A92CE503'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '14.128.32.0',
#    '8192',
#    '20100914',
#    'allocated',
#    'A918C661'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.128.64.0',
#    '8192',
#    '20100920',
#    'allocated',
#    'A92E7AC2'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.128.96.0',
#    '8192',
#    '20100920',
#    'allocated',
#    'A9290F05'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.128.128.0',
#    '32768',
#    '20100915',
#    'allocated',
#    'A925375E'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.129.0.0',
#    '65536',
#    '20100812',
#    'allocated',
#    'A9243CD3'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.130.0.0',
#    '131072',
#    '20100818',
#    'allocated',
#    'A9257BC7'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.132.0.0',
#    '131072',
#    '20100901',
#    'allocated',
#    'A92F35B6'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.134.0.0',
#    '131072',
#    '20100902',
#    'allocated',
#    'A92F152F'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.136.0.0',
#    '65536',
#    '20100906',
#    'allocated',
#    'A911647C'],
#   ['apnic',
#    'NZ',
#    'ipv4',
#    '14.137.0.0',
#    '8192',
#    '20100909',
#    'allocated',
#    'A91BC269'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '14.137.32.0',
#    '8192',
#    '20100909',
#    'allocated',
#    'A917F247'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '14.137.64.0',
#    '16384',
#    '20100909',
#    'allocated',
#    'A91EAE3D'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '14.137.128.0',
#    '16384',
#    '20100909',
#    'allocated',
#    'A917E678'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '14.137.192.0',
#    '8192',
#    '20100909',
#    'allocated',
#    'A91EAE3D'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.137.224.0',
#    '8192',
#    '20110307',
#    'allocated',
#    'A912C253'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.138.0.0',
#    '65536',
#    '20100909',
#    'allocated',
#    'A926D98F'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.139.0.0',
#    '65536',
#    '20100914',
#    'allocated',
#    'A914BC7A'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.140.0.0',
#    '262144',
#    '20100907',
#    'allocated',
#    'A914CE75'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.144.0.0',
#    '1048576',
#    '20100906',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'VN',
#    'ipv4',
#    '14.160.0.0',
#    '2097152',
#    '20100816',
#    'allocated',
#    'A92BA6BC'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.192.0.0',
#    '1024',
#    '20160113',
#    'assigned',
#    'A92A99BB'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.192.4.0',
#    '1024',
#    '20160113',
#    'allocated',
#    'A912F535'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.192.8.0',
#    '1024',
#    '20160113',
#    'allocated',
#    'A91233D4'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.192.12.0',
#    '1024',
#    '20160113',
#    'assigned',
#    'A92891C5'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.192.16.0',
#    '1024',
#    '20160114',
#    'allocated',
#    'A915B5D0'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.192.20.0',
#    '1024',
#    '20160114',
#    'allocated',
#    'A912D362'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.192.24.0',
#    '1024',
#    '20160114',
#    'assigned',
#    'A9221C40'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.192.28.0',
#    '1024',
#    '20160114',
#    'assigned',
#    'A922D1A3'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.192.32.0',
#    '4096',
#    '20100921',
#    'allocated',
#    'A929C680'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.192.48.0',
#    '1024',
#    '20180808',
#    'allocated',
#    'A914E93F'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.192.52.0',
#    '1024',
#    '20160715',
#    'assigned',
#    'A9292FD7'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '14.192.56.0',
#    '1024',
#    '20180808',
#    'allocated',
#    'A91BCAC5'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.192.60.0',
#    '1024',
#    '20100927',
#    'allocated',
#    'A926F339'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.192.64.0',
#    '256',
#    '20100915',
#    'allocated',
#    'A9127B77'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.192.65.0',
#    '256',
#    '20100915',
#    'allocated',
#    'A9156342'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.192.66.0',
#    '256',
#    '20100915',
#    'allocated',
#    'A9127B77'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.192.67.0',
#    '256',
#    '20100915',
#    'allocated',
#    'A912176D'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.192.68.0',
#    '512',
#    '20100915',
#    'allocated',
#    'A912176D'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.192.70.0',
#    '512',
#    '20100915',
#    'allocated',
#    'A9127B77'],
#   ['apnic',
#    'PG',
#    'ipv4',
#    '14.192.72.0',
#    '1024',
#    '20100914',
#    'allocated',
#    'A91D8117'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.192.76.0',
#    '1024',
#    '20110414',
#    'allocated',
#    'A92E1062'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.192.80.0',
#    '4096',
#    '20100920',
#    'allocated',
#    'A926EF31'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.192.96.0',
#    '8192',
#    '20100914',
#    'allocated',
#    'A92A756D'],
#   ['apnic',
#    'PK',
#    'ipv4',
#    '14.192.128.0',
#    '8192',
#    '20100922',
#    'allocated',
#    'A915A0CD'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '14.192.160.0',
#    '8192',
#    '20100928',
#    'allocated',
#    'A918919A'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '14.192.192.0',
#    '16384',
#    '20100927',
#    'allocated',
#    'A9144633'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '14.193.0.0',
#    '65536',
#    '20100816',
#    'allocated',
#    'A92B1B09'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '14.194.0.0',
#    '131072',
#    '20100819',
#    'allocated',
#    'A9157D7A'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.196.0.0',
#    '131072',
#    '20100903',
#    'allocated',
#    'A92B15BB'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.198.0.0',
#    '32768',
#    '20100906',
#    'allocated',
#    'A911647C'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.198.128.0',
#    '16384',
#    '20100906',
#    'allocated',
#    'A911647C'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.198.192.0',
#    '8192',
#    '20100906',
#    'allocated',
#    'A911647C'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.198.224.0',
#    '4096',
#    '20100906',
#    'allocated',
#    'A911647C'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.198.240.0',
#    '4096',
#    '20100906',
#    'allocated',
#    'A9166732'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '14.199.0.0',
#    '65536',
#    '20100906',
#    'allocated',
#    'A911647C'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '14.200.0.0',
#    '262144',
#    '20100914',
#    'allocated',
#    'A9117E4D'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.204.0.0',
#    '131072',
#    '20100917',
#    'allocated',
#    'A92FC194'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '14.206.0.0',
#    '65536',
#    '20100920',
#    'allocated',
#    'A9222FAD'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '14.207.0.0',
#    '65536',
#    '20100920',
#    'allocated',
#    'A91E7561'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '14.208.0.0',
#    '1048576',
#    '20100906',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'VN',
#    'ipv4',
#    '14.224.0.0',
#    '2097152',
#    '20100816',
#    'allocated',
#    'A92BA6BC'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '23.81.40.0',
#    '2048',
#    '20130506',
#    'allocated',
#    'A91A9083'],
#   ['apnic',
#    'AF',
#    'ipv4',
#    '23.88.192.0',
#    '8192',
#    '20130607',
#    'allocated',
#    'A9148C7B'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '23.90.68.0',
#    '256',
#    '20130807',
#    'assigned',
#    'A915DE37'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '23.106.48.0',
#    '2048',
#    '20130724',
#    'allocated',
#    'A916AC30'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '23.106.120.0',
#    '2048',
#    '20130724',
#    'allocated',
#    'A916AC30'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '23.106.224.0',
#    '2048',
#    '20130724',
#    'allocated',
#    'A91A9083'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '23.106.240.0',
#    '2048',
#    '20130724',
#    'allocated',
#    'A9184AB8'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '23.106.248.0',
#    '2048',
#    '20130724',
#    'allocated',
#    'A916AC30'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '23.108.96.0',
#    '2048',
#    '20130724',
#    'allocated',
#    'A916AC30'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '23.111.12.0',
#    '1024',
#    '20090424',
#    'allocated',
#    'A916AC30'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '23.226.0.0',
#    '4096',
#    '20130909',
#    'allocated',
#    'A91CEF3E'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '23.232.128.0',
#    '32768',
#    '20130923',
#    'allocated',
#    'A92D890B'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '24.41.112.0',
#    '4096',
#    '20131114',
#    'allocated',
#    'A928D03C'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '24.53.192.0',
#    '8192',
#    '20141007',
#    'allocated',
#    'A92DF1C2'],
#   ['apnic',
#    'FR',
#    'ipv4',
#    '24.230.0.0',
#    '8192',
#    '19971009',
#    'allocated',
#    'A91ADED5'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '24.233.128.0',
#    '4096',
#    '20021007',
#    'allocated',
#    'A918DB28'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '24.235.24.0',
#    '2048',
#    '19970128',
#    'allocated',
#    'A9193B0C'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.0.0.0',
#    '1024',
#    '20100611',
#    'allocated',
#    'A91F635F'],
#   ['apnic',
#    'MY',
#    'ipv4',
#    '27.0.4.0',
#    '1024',
#    '20100310',
#    'allocated',
#    'A9131F8A'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '27.0.8.0',
#    '1024',
#    '20100312',
#    'allocated',
#    'A912F17E'],
#   ['apnic',
#    'VN',
#    'ipv4',
#    '27.0.12.0',
#    '1024',
#    '20100315',
#    'allocated',
#    'A92D5F04'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.0.16.0',
#    '4096',
#    '20100310',
#    'allocated',
#    'A92F22AB'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.0.32.0',
#    '4096',
#    '20100315',
#    'allocated',
#    'A92FD0A1'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.48.0',
#    '4096',
#    '20100316',
#    'allocated',
#    'A92C5573'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.0.64.0',
#    '8192',
#    '20100316',
#    'allocated',
#    'A91EAE3D'],
#   ['apnic',
#    'BD',
#    'ipv4',
#    '27.0.96.0',
#    '8192',
#    '20110302',
#    'allocated',
#    'A9140908'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.0.128.0',
#    '1024',
#    '20160129',
#    'allocated',
#    'A9268CC9'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.0.132.0',
#    '1024',
#    '20160129',
#    'allocated',
#    'A92375A6'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.136.0',
#    '1024',
#    '20160129',
#    'allocated',
#    'A923FB01'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.140.0',
#    '1024',
#    '20160129',
#    'allocated',
#    'A92BCD1F'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.144.0',
#    '1024',
#    '20160129',
#    'allocated',
#    'A92143C7'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.148.0',
#    '1024',
#    '20160129',
#    'allocated',
#    'A9223775'],
#   ['apnic',
#    'TW',
#    'ipv4',
#    '27.0.152.0',
#    '1024',
#    '20160129',
#    'allocated',
#    'A92B969D'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '27.0.156.0',
#    '1024',
#    '20160201',
#    'allocated',
#    'A91AF3E2'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.0.160.0',
#    '1024',
#    '20160201',
#    'allocated',
#    'A9237638'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.0.164.0',
#    '1024',
#    '20160201',
#    'allocated',
#    'A92C1173'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.168.0',
#    '1024',
#    '20160201',
#    'assigned',
#    'A92BA79D'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.176.0',
#    '1024',
#    '20160201',
#    'allocated',
#    'A921585D'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.180.0',
#    '1024',
#    '20160201',
#    'allocated',
#    'A92740FE'],
#   ['apnic',
#    'PK',
#    'ipv4',
#    '27.0.184.0',
#    '1024',
#    '20160201',
#    'allocated',
#    'A91B1185'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.0.188.0',
#    '1024',
#    '20160201',
#    'allocated',
#    'A92A6793'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '27.0.192.0',
#    '1024',
#    '20160202',
#    'allocated',
#    'A911EDC4'],
#   ['apnic',
#    'ID',
#    'ipv4',
#    '27.0.196.0',
#    '1024',
#    '20160202',
#    'assigned',
#    'A92A03BD'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.200.0',
#    '1024',
#    '20160202',
#    'assigned',
#    'A92EFF92'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.0.204.0',
#    '1024',
#    '20160202',
#    'allocated',
#    'A92FF4CC'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.0.208.0',
#    '1024',
#    '20160202',
#    'allocated',
#    'A928EC19'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.0.212.0',
#    '1024',
#    '20160202',
#    'allocated',
#    'A92CC7FD'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.216.0',
#    '1024',
#    '20160202',
#    'assigned',
#    'A92421BE'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.220.0',
#    '1024',
#    '20160202',
#    'allocated',
#    'A92421BE'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.228.0',
#    '1024',
#    '20160202',
#    'assigned',
#    'A92193CD'],
#   ['apnic',
#    'NZ',
#    'ipv4',
#    '27.0.232.0',
#    '1024',
#    '20160203',
#    'allocated',
#    'A9111590'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.0.236.0',
#    '1024',
#    '20160203',
#    'allocated',
#    'A9250A2A'],
#   ['apnic',
#    'VN',
#    'ipv4',
#    '27.0.240.0',
#    '1024',
#    '20160203',
#    'allocated',
#    'A92B7ABC'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.244.0',
#    '1024',
#    '20160203',
#    'assigned',
#    'A92421BE'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.248.0',
#    '1024',
#    '20160203',
#    'assigned',
#    'A92421BE'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.0.252.0',
#    '1024',
#    '20160203',
#    'assigned',
#    'A92A8D3A'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.1.0.0',
#    '65536',
#    '20100310',
#    'allocated',
#    'A926D98F'],
#   ['apnic',
#    'VN',
#    'ipv4',
#    '27.2.0.0',
#    '131072',
#    '20100311',
#    'allocated',
#    'A92266C0'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.4.0.0',
#    '262144',
#    '20100311',
#    'allocated',
#    'A91B1B8D'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.8.0.0',
#    '524288',
#    '20100311',
#    'allocated',
#    'A927D1BA'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.16.0.0',
#    '1048576',
#    '20100318',
#    'allocated',
#    'A923488A'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.32.0.0',
#    '131072',
#    '20100318',
#    'allocated',
#    'A9117E4D'],
#   ['apnic',
#    'NP',
#    'ipv4',
#    '27.34.0.0',
#    '32768',
#    '20100322',
#    'allocated',
#    'A91F731E'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.34.128.0',
#    '8192',
#    '20100325',
#    'allocated',
#    'A926EE4C'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.34.160.0',
#    '2048',
#    '20100325',
#    'allocated',
#    'A926EE4C'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.34.168.0',
#    '2048',
#    '20100326',
#    'allocated',
#    'A92D52F3'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '27.34.176.0',
#    '4096',
#    '20100330',
#    'allocated',
#    'A91BEE8E'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.34.192.0',
#    '8192',
#    '20100325',
#    'allocated',
#    'A92D4FEB'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.34.224.0',
#    '2048',
#    '20100330',
#    'allocated',
#    'A91A81EE'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.34.232.0',
#    '2048',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.34.240.0',
#    '4096',
#    '20100408',
#    'allocated',
#    'A91C39D1'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.35.0.0',
#    '65536',
#    '20100324',
#    'allocated',
#    'A922606A'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.36.0.0',
#    '262144',
#    '20100323',
#    'allocated',
#    'A9285C93'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.40.0.0',
#    '524288',
#    '20100323',
#    'allocated',
#    'A9285C93'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.48.0.0',
#    '65536',
#    '20100311',
#    'allocated',
#    'A92D8633'],
#   ['apnic',
#    'PH',
#    'ipv4',
#    '27.49.0.0',
#    '65536',
#    '20100311',
#    'allocated',
#    'A916B18B'],
#   ['apnic',
#    'PH',
#    'ipv4',
#    '27.50.0.0',
#    '1024',
#    '20100611',
#    'allocated',
#    'A91C49C4'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.50.4.0',
#    '1024',
#    '20100311',
#    'allocated',
#    'A9124BD3'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.50.8.0',
#    '1024',
#    '20160913',
#    'allocated',
#    'A91CD7A4'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.50.12.0',
#    '1024',
#    '20100317',
#    'allocated',
#    'A91F182D'],
#   ['apnic',
#    'ID',
#    'ipv4',
#    '27.50.16.0',
#    '4096',
#    '20100311',
#    'allocated',
#    'A929DE95'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '27.50.32.0',
#    '2048',
#    '20100316',
#    'allocated',
#    'A91474C3'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.50.40.0',
#    '2048',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '27.50.48.0',
#    '4096',
#    '20100317',
#    'allocated',
#    'A918C661'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.50.64.0',
#    '8192',
#    '20100317',
#    'allocated',
#    'A911FDBA'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.50.96.0',
#    '8192',
#    '20110304',
#    'allocated',
#    'A9291BA6'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.50.128.0',
#    '32768',
#    '20100317',
#    'allocated',
#    'A9288579'],
#   ['apnic',
#    'TW',
#    'ipv4',
#    '27.51.0.0',
#    '65536',
#    '20100312',
#    'allocated',
#    'A92B65E5'],
#   ['apnic',
#    'TW',
#    'ipv4',
#    '27.52.0.0',
#    '131072',
#    '20100312',
#    'allocated',
#    'A92B65E5'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '27.54.0.0',
#    '16384',
#    '20100317',
#    'allocated',
#    'A91402DC'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.54.64.0',
#    '2048',
#    '20100318',
#    'allocated',
#    'A914E3B7'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.54.72.0',
#    '2048',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.54.80.0',
#    '2048',
#    '20100318',
#    'allocated',
#    'A91D3794'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.54.88.0',
#    '2048',
#    '20110324',
#    'allocated',
#    'A91D3794'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.54.96.0',
#    '4096',
#    '20100322',
#    'allocated',
#    'A9291275'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.54.112.0',
#    '1024',
#    '20100322',
#    'allocated',
#    'A9291275'],
#   ['apnic',
#    'ID',
#    'ipv4',
#    '27.54.116.0',
#    '1024',
#    '20151103',
#    'allocated',
#    'A92BA586'],
#   ['apnic',
#    'PK',
#    'ipv4',
#    '27.54.120.0',
#    '1024',
#    '20100324',
#    'allocated',
#    'A91D1003'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.54.124.0',
#    '1024',
#    '20100326',
#    'allocated',
#    'A923CC53'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.54.128.0',
#    '4096',
#    '20100322',
#    'allocated',
#    'A9119AE2'],
#   ['apnic',
#    'BD',
#    'ipv4',
#    '27.54.144.0',
#    '1024',
#    '20151214',
#    'allocated',
#    'A915C281'],
#   ['apnic',
#    'BD',
#    'ipv4',
#    '27.54.148.0',
#    '1024',
#    '20151214',
#    'allocated',
#    'A9175300'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.54.152.0',
#    '2048',
#    '20110412',
#    'allocated',
#    'A92319D5'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.54.160.0',
#    '8192',
#    '20100325',
#    'allocated',
#    'A929FC91'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.54.192.0',
#    '16384',
#    '20100325',
#    'allocated',
#    'A923BF97'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '27.55.0.0',
#    '65536',
#    '20100319',
#    'allocated',
#    'A919EDE5'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.56.0.0',
#    '524288',
#    '20100312',
#    'allocated',
#    'A9199197'],
#   ['apnic',
#    'VN',
#    'ipv4',
#    '27.64.0.0',
#    '1048576',
#    '20100427',
#    'allocated',
#    'A92793A5'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.80.0.0',
#    '1048576',
#    '20100428',
#    'allocated',
#    'A92D830B'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.96.0.0',
#    '4096',
#    '20100514',
#    'allocated',
#    'A92FD2D3'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.96.16.0',
#    '2048',
#    '20100518',
#    'allocated',
#    'A9224AEC'],
#   ['apnic',
#    'TK',
#    'ipv4',
#    '27.96.24.0',
#    '2048',
#    '20100518',
#    'allocated',
#    'A9172B7E'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.96.32.0',
#    '8192',
#    '20100518',
#    'allocated',
#    'A9224AEC'],
#   ['apnic',
#    'NZ',
#    'ipv4',
#    '27.96.64.0',
#    '1024',
#    '20100519',
#    'allocated',
#    'A9116B83'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.96.68.0',
#    '1024',
#    '20110221',
#    'allocated',
#    'A926431E'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.96.72.0',
#    '2048',
#    '20100519',
#    'allocated',
#    'A92F702B'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.96.80.0',
#    '1024',
#    '20100519',
#    'allocated',
#    'A92F702B'],
#   ['apnic',
#    'KH',
#    'ipv4',
#    '27.96.84.0',
#    '1024',
#    '20100520',
#    'allocated',
#    'A913621A'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.96.88.0',
#    '1024',
#    '20151104',
#    'allocated',
#    'A927FE87'],
#   ['apnic',
#    'PK',
#    'ipv4',
#    '27.96.92.0',
#    '1024',
#    '20150925',
#    'allocated',
#    'A91E7164'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '27.96.96.0',
#    '8192',
#    '20100519',
#    'allocated',
#    'A9136DD6'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.96.128.0',
#    '2048',
#    '20100519',
#    'allocated',
#    'A922EE53'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.96.136.0',
#    '2048',
#    '20100519',
#    'allocated',
#    'A9260DE5'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.96.144.0',
#    '4096',
#    '20100519',
#    'allocated',
#    'A922EE53'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.96.160.0',
#    '8192',
#    '20100519',
#    'allocated',
#    'A922EE53'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.96.192.0',
#    '8192',
#    '20100520',
#    'allocated',
#    'A915C631'],
#   ['apnic',
#    'TW',
#    'ipv4',
#    '27.96.224.0',
#    '8192',
#    '20110304',
#    'allocated',
#    'A92EDCF6'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.97.0.0',
#    '65536',
#    '20100517',
#    'allocated',
#    'A929E0AE'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.98.0.0',
#    '32768',
#    '20100520',
#    'allocated',
#    'A926971F'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.98.128.0',
#    '16384',
#    '20100520',
#    'allocated',
#    'A926971F'],
#   ['apnic', '', 'ipv4', '27.98.192.0', '4096', '', 'available', ''],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.98.208.0',
#    '4096',
#    '20100525',
#    'allocated',
#    'A92BC92E'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.98.224.0',
#    '8192',
#    '20100524',
#    'allocated',
#    'A92FBBB4'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.99.0.0',
#    '32768',
#    '20100524',
#    'allocated',
#    'A915A300'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.99.128.0',
#    '32768',
#    '20110125',
#    'allocated',
#    'A9239DAE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.100.0.0',
#    '1024',
#    '20100525',
#    'allocated',
#    'A9146D58'],
#   ['apnic', '', 'ipv4', '27.100.4.0', '1024', '', 'reserved', ''],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.100.8.0',
#    '1024',
#    '20100527',
#    'allocated',
#    'A9237870'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.100.12.0',
#    '1024',
#    '20100602',
#    'allocated',
#    'A92E3015'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '27.100.16.0',
#    '2048',
#    '20100531',
#    'allocated',
#    'A9169A53'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.100.24.0',
#    '1024',
#    '20151104',
#    'allocated',
#    'A9240149'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.100.28.0',
#    '1024',
#    '20110222',
#    'allocated',
#    'A929F254'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.100.32.0',
#    '1024',
#    '20100602',
#    'allocated',
#    'A92AA1FF'],
#   ['apnic',
#    'US',
#    'ipv4',
#    '27.100.36.0',
#    '1024',
#    '20151104',
#    'allocated',
#    'A911C28D'],
#   ['apnic',
#    'TH',
#    'ipv4',
#    '27.100.40.0',
#    '2048',
#    '20100603',
#    'allocated',
#    'A911BD54'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.100.48.0',
#    '4096',
#    '20100603',
#    'allocated',
#    'A925C910'],
#   ['apnic',
#    'TW',
#    'ipv4',
#    '27.100.64.0',
#    '16384',
#    '20100528',
#    'allocated',
#    'A92F8986'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.100.128.0',
#    '32768',
#    '20100531',
#    'allocated',
#    'A92E9287'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.101.0.0',
#    '65536',
#    '20100525',
#    'allocated',
#    'A923CC4A'],
#   ['apnic',
#    'KR',
#    'ipv4',
#    '27.102.0.0',
#    '65536',
#    '20100527',
#    'allocated',
#    'A9222B0E'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.103.0.0',
#    '65536',
#    '20100528',
#    'allocated',
#    'A929E16F'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '27.104.0.0',
#    '65536',
#    '20100528',
#    'allocated',
#    'A91DE7DE'],
#   ['apnic',
#    'TW',
#    'ipv4',
#    '27.105.0.0',
#    '65536',
#    '20100601',
#    'allocated',
#    'A9264F38'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '27.106.0.0',
#    '16384',
#    '20100607',
#    'allocated',
#    'A917E678'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.106.64.0',
#    '16384',
#    '20100607',
#    'allocated',
#    'A92B8DED'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.106.128.0',
#    '16384',
#    '20100608',
#    'allocated',
#    'A92413BE'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.106.192.0',
#    '2048',
#    '20100608',
#    'allocated',
#    'A91EAE3D'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.106.200.0',
#    '1024',
#    '20100609',
#    'allocated',
#    'A91EAE3D'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.106.204.0',
#    '1024',
#    '20110225',
#    'allocated',
#    'A92D07E1'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.106.208.0',
#    '2048',
#    '20100611',
#    'allocated',
#    'A92DF1C2'],
#   ['apnic',
#    'PH',
#    'ipv4',
#    '27.106.216.0',
#    '2048',
#    '20100611',
#    'allocated',
#    'A919D539'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.106.224.0',
#    '8192',
#    '20100611',
#    'allocated',
#    'A92DF1C2'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.107.0.0',
#    '65536',
#    '20100607',
#    'allocated',
#    'A9157D7A'],
#   ['apnic',
#    'PH',
#    'ipv4',
#    '27.108.0.0',
#    '65536',
#    '20100608',
#    'allocated',
#    'A91709BC'],
#   ['apnic',
#    'IN',
#    'ipv4',
#    '27.109.0.0',
#    '8192',
#    '20100608',
#    'allocated',
#    'A914A0CB'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.109.32.0',
#    '8192',
#    '20110307',
#    'allocated',
#    'A923A32F'],
#   ['apnic',
#    'PH',
#    'ipv4',
#    '27.109.64.0',
#    '8192',
#    '20100611',
#    'allocated',
#    'A91DE2B2'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.109.96.0',
#    '2048',
#    '20100617',
#    'allocated',
#    'A9282B08'],
#   ['apnic',
#    'SG',
#    'ipv4',
#    '27.109.104.0',
#    '1024',
#    '20100618',
#    'allocated',
#    'A91EDFAF'],
#   ['apnic',
#    'AU',
#    'ipv4',
#    '27.109.108.0',
#    '1024',
#    '20100618',
#    'allocated',
#    'A91D1128'],
#   ['apnic',
#    'KH',
#    'ipv4',
#    '27.109.112.0',
#    '1024',
#    '20100622',
#    'allocated',
#    'A91E2364'],
#   ['apnic',
#    'MM',
#    'ipv4',
#    '27.109.116.0',
#    '1024',
#    '20100622',
#    'allocated',
#    'A9171560'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.109.120.0',
#    '1024',
#    '20100623',
#    'allocated',
#    'A9233FF1'],
#   ['apnic',
#    'CN',
#    'ipv4',
#    '27.109.124.0',
#    '1024',
#    '20151104',
#    'allocated',
#    'A9255FB9'],
#   ['apnic',
#    'MO',
#    'ipv4',
#    '27.109.128.0',
#    '32768',
#    '20100610',
#    'allocated',
#    'A91F3FAF'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.110.0.0',
#    '4096',
#    '20100624',
#    'allocated',
#    'A914C4ED'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.110.16.0',
#    '1024',
#    '20100624',
#    'allocated',
#    'A914C4ED'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.110.20.0',
#    '1024',
#    '20100623',
#    'allocated',
#    'A92DDE0D'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.110.24.0',
#    '2048',
#    '20100623',
#    'allocated',
#    'A92DDE0D'],
#   ['apnic',
#    'JP',
#    'ipv4',
#    '27.110.32.0',
#    '8192',
#    '20100623',
#    'allocated',
#    'A92DDE0D'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '27.110.64.0',
#    '2048',
#    '20100624',
#    'allocated',
#    'A9186755'],
#   ['apnic',
#    'HK',
#    'ipv4',
#    '27.110.72.0',
#    '2048',
# ...
#    'a864add8-2cf6-4362-91e1-9130976f4be1'],
#   ['ripencc',
#    'IT',
#    'ipv4',
#    '5.133.32.0',
#    '2048',
#    '20120704',
#    'allocated',
#    '2c314bdd-7238-4f0c-8f32-33a81cb6bc47'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.133.40.0',
#    '2048',
#    '20120705',
#    'allocated',
#    '9ceebc55-15c5-4502-a423-d89023537231'],
#   ['ripencc',
#    'IT',
#    'ipv4',
#    '5.133.48.0',
#    '4096',
#    '20120705',
#    'allocated',
#    '19bddb00-7b3e-4a11-85dd-fd3b9108bac5'],
#   ['ripencc',
#    'LT',
#    'ipv4',
#    '5.133.64.0',
#    '1024',
#    '20181109',
#    'allocated',
#    'd69b4499-bad8-4bf3-831c-0147008b4531'],
#   ['ripencc',
#    'FR',
#    'ipv4',
#    '5.133.68.0',
#    '1024',
#    '20181109',
#    'allocated',
#    'dc08ce3f-3145-412c-9725-8a0d9c5b2185'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.133.72.0',
#    '1024',
#    '20181109',
#    'allocated',
#    'd9fe5541-1818-4ac8-a653-e21469cc8bd7'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.133.76.0',
#    '1024',
#    '20181109',
#    'allocated',
#    'db5eee97-d302-4518-8d3f-7169a703059c'],
#   ['ripencc',
#    'AE',
#    'ipv4',
#    '5.133.80.0',
#    '1024',
#    '20181109',
#    'allocated',
#    '2f3115d9-ff54-4d7c-bb1f-c0d56dc4c604'],
#   ['ripencc',
#    'NL',
#    'ipv4',
#    '5.133.84.0',
#    '1024',
#    '20181109',
#    'allocated',
#    '2753afce-5d53-42bc-856b-66101a3cd4f2'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.133.88.0',
#    '1024',
#    '20181109',
#    'allocated',
#    '463d5236-bf88-470f-a24d-35e132941af8'],
#   ['ripencc',
#    'BG',
#    'ipv4',
#    '5.133.92.0',
#    '1024',
#    '20181109',
#    'allocated',
#    '5a1a466f-3219-4e86-a814-d20e317e71ed'],
#   ['ripencc',
#    'IT',
#    'ipv4',
#    '5.133.96.0',
#    '1024',
#    '20181109',
#    'allocated',
#    'c0ff2b19-b42f-4297-be20-4e2b07892347'],
#   ['ripencc',
#    'TR',
#    'ipv4',
#    '5.133.100.0',
#    '1024',
#    '20181109',
#    'allocated',
#    '9456c0a4-5f16-435b-a3b3-91f576d1eb93'],
#   ['ripencc',
#    'FI',
#    'ipv4',
#    '5.133.104.0',
#    '1024',
#    '20181109',
#    'allocated',
#    '516e5a57-df88-4228-ade4-d58f973ccbfb'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.133.108.0',
#    '1024',
#    '20181109',
#    'allocated',
#    '98a62944-24cb-4b83-882e-0aaddfcafe4d'],
#   ['ripencc',
#    'DE',
#    'ipv4',
#    '5.133.112.0',
#    '256',
#    '20200925',
#    'allocated',
#    '36e49c29-5532-4ced-84e4-77097d9c489f'],
#   ['ripencc',
#    'FR',
#    'ipv4',
#    '5.133.113.0',
#    '256',
#    '20200925',
#    'allocated',
#    '45e13f4b-24ea-4eee-9aa8-5022a536d149'],
#   ['ripencc',
#    'IT',
#    'ipv4',
#    '5.133.114.0',
#    '256',
#    '20200925',
#    'allocated',
#    'a18cfab0-4871-4164-947b-59eb6b6e3bae'],
#   ['ripencc',
#    'PL',
#    'ipv4',
#    '5.133.115.0',
#    '256',
#    '20200928',
#    'allocated',
#    '592d3469-1c66-4091-8ac1-414d00726caf'],
#   ['ripencc',
#    'DE',
#    'ipv4',
#    '5.133.116.0',
#    '1024',
#    '20181109',
#    'allocated',
#    'c45f0bac-c375-4b40-8176-2c62778a3e0c'],
#   ['ripencc',
#    'UZ',
#    'ipv4',
#    '5.133.120.0',
#    '1024',
#    '20181109',
#    'allocated',
#    '325e8015-4425-4ca0-a951-5c67a0ffa64a'],
#   ['ripencc',
#    'TR',
#    'ipv4',
#    '5.133.124.0',
#    '1024',
#    '20181109',
#    'allocated',
#    '9456c0a4-5f16-435b-a3b3-91f576d1eb93'],
#   ['ripencc',
#    'BA',
#    'ipv4',
#    '5.133.128.0',
#    '8192',
#    '20120704',
#    'allocated',
#    '8073eea8-f85c-4ba5-a3f1-bc8ba95e57a4'],
#   ['ripencc',
#    'GE',
#    'ipv4',
#    '5.133.160.0',
#    '2048',
#    '20120705',
#    'allocated',
#    '51b27ecc-929b-47e6-9b17-33d6f3184753'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.133.168.0',
#    '1024',
#    '20120705',
#    'allocated',
#    'c95f94f4-776c-49c4-8f7b-6db94c6a1b3e'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.133.172.0',
#    '1024',
#    '20120705',
#    'allocated',
#    'c19af06e-715c-454f-9458-0f03b2e64824'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.133.176.0',
#    '2048',
#    '20120705',
#    'allocated',
#    '52b8b380-a426-49c6-af27-9e955ac45093'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.133.184.0',
#    '2048',
#    '20120705',
#    'allocated',
#    '931e50b5-ec9d-4c18-9901-ba3a010862dc'],
#   ['ripencc',
#    'SE',
#    'ipv4',
#    '5.133.192.0',
#    '8192',
#    '20120705',
#    'allocated',
#    'b1444cb2-1d3d-4eb6-9d15-c93d5f1e5fb7'],
#   ['ripencc',
#    'AZ',
#    'ipv4',
#    '5.133.224.0',
#    '4096',
#    '20120705',
#    'allocated',
#    '4421c7c9-c7d1-4e89-851f-4b1700c1360f'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.133.240.0',
#    '2048',
#    '20120706',
#    'allocated',
#    '8effbcf4-e700-4674-84c6-d4f1f5a88a98'],
#   ['ripencc',
#    'PL',
#    'ipv4',
#    '5.133.248.0',
#    '2048',
#    '20120706',
#    'allocated',
#    '3848367a-64ca-4c51-8490-e20f9ab61450'],
#   ['ripencc',
#    'BE',
#    'ipv4',
#    '5.134.0.0',
#    '2048',
#    '20120706',
#    'allocated',
#    '59f944e4-ff59-47e7-b0d7-ed5f9e6360d9'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.134.8.0',
#    '2048',
#    '20120706',
#    'allocated',
#    '447d4bc9-16e2-4aa4-b2fb-32582687e5b3'],
#   ['ripencc',
#    'DE',
#    'ipv4',
#    '5.134.16.0',
#    '2048',
#    '20120706',
#    'allocated',
#    '98626b16-3b80-4394-b6d8-87b865ad1513'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.134.24.0',
#    '2048',
#    '20120709',
#    'allocated',
#    '7eefad46-c077-42ee-a67f-d2a2e44ef36e'],
#   ['ripencc',
#    'ES',
#    'ipv4',
#    '5.134.32.0',
#    '4096',
#    '20120706',
#    'allocated',
#    '05a56d7a-bee4-4020-afdc-4bb69c2789f6'],
#   ['ripencc',
#    'AZ',
#    'ipv4',
#    '5.134.48.0',
#    '4096',
#    '20120709',
#    'allocated',
#    '01dd748a-d154-490c-9190-03a9ca35547d'],
#   ['ripencc',
#    'PL',
#    'ipv4',
#    '5.134.64.0',
#    '4096',
#    '20120709',
#    'allocated',
#    'ba3a1f56-da67-4101-8032-58d52fe9e562'],
#   ['ripencc',
#    'AM',
#    'ipv4',
#    '5.134.80.0',
#    '2048',
#    '20120709',
#    'allocated',
#    'fdccd160-0e58-4e28-84cc-ba5759eb7f9a'],
#   ['ripencc',
#    'IE',
#    'ipv4',
#    '5.134.88.0',
#    '2048',
#    '20120710',
#    'allocated',
#    'd9dd058f-1644-48ac-a3f2-f9e7ae5f8799'],
#   ['ripencc',
#    'FR',
#    'ipv4',
#    '5.134.96.0',
#    '2048',
#    '20120710',
#    'allocated',
#    '364da66b-3dba-4019-9f4d-12921b6871bd'],
#   ['ripencc',
#    'RS',
#    'ipv4',
#    '5.134.104.0',
#    '2048',
#    '20120710',
#    'allocated',
#    'd4fbefcf-fa6b-43b3-a101-fcc60ad6c79b'],
#   ['ripencc',
#    'ES',
#    'ipv4',
#    '5.134.112.0',
#    '2048',
#    '20120710',
#    'allocated',
#    'ad4311a9-0243-44aa-8bca-1ec5bf5bfff0'],
#   ['ripencc',
#    'IT',
#    'ipv4',
#    '5.134.120.0',
#    '2048',
#    '20120710',
#    'allocated',
#    '7a80cc3c-4632-45f2-9b5e-509287e7a952'],
#   ['ripencc',
#    'IR',
#    'ipv4',
#    '5.134.128.0',
#    '16384',
#    '20120710',
#    'allocated',
#    'cd4f5c8c-dab4-4c71-8493-add1a0e5227f'],
#   ['ripencc',
#    'IR',
#    'ipv4',
#    '5.134.192.0',
#    '2048',
#    '20120710',
#    'allocated',
#    '712e171f-048f-4c97-8034-f98e78adedca'],
#   ['ripencc',
#    'SY',
#    'ipv4',
#    '5.134.200.0',
#    '2048',
#    '20120710',
#    'allocated',
#    'c9e6dd0b-19b5-4816-910e-10f9ffaea394'],
#   ['ripencc',
#    'PL',
#    'ipv4',
#    '5.134.208.0',
#    '2048',
#    '20120711',
#    'allocated',
#    '233cd2d4-7d71-450e-aaac-018375169251'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.134.216.0',
#    '2048',
#    '20120711',
#    'allocated',
#    '9dfad9b7-098d-4dec-8417-2878c61c0911'],
#   ['ripencc',
#    'SY',
#    'ipv4',
#    '5.134.224.0',
#    '8192',
#    '20120710',
#    'allocated',
#    'c9e6dd0b-19b5-4816-910e-10f9ffaea394'],
#   ['ripencc',
#    'FR',
#    'ipv4',
#    '5.135.0.0',
#    '65536',
#    '20120706',
#    'allocated',
#    'f5d74be3-67a5-4b44-9bee-583bd2698227'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.136.0.0',
#    '524288',
#    '20120703',
#    'allocated',
#    '6d4dd4d8-f11d-4e76-ae1c-3a74bdc55e7d'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.144.0.0',
#    '8192',
#    '20120711',
#    'allocated',
#    '6819bd99-701f-4fbd-9b04-ea84cee1611a'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.144.32.0',
#    '2048',
#    '20120711',
#    'allocated',
#    'ce424108-9744-40af-b731-169f840e7402'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.144.40.0',
#    '2048',
#    '20120711',
#    'allocated',
#    '6cd1457c-ab0b-4eff-8682-54acf6c6bf14'],
#   ['ripencc',
#    'IL',
#    'ipv4',
#    '5.144.48.0',
#    '4096',
#    '20120711',
#    'allocated',
#    '7f559191-eeba-4ca1-a518-82e81191d223'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.144.64.0',
#    '4096',
#    '20120711',
#    'allocated',
#    'ea8a3c73-09b1-48a3-9c7d-e1362e2270f4'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.144.80.0',
#    '4096',
#    '20120711',
#    'allocated',
#    '6501a6ef-5472-4528-916d-bdab08ebf6d5'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.144.96.0',
#    '8192',
#    '20120711',
#    'allocated',
#    'ea8a3c73-09b1-48a3-9c7d-e1362e2270f4'],
#   ['ripencc',
#    'IR',
#    'ipv4',
#    '5.144.128.0',
#    '2048',
#    '20120711',
#    'allocated',
#    '04a3ebf2-016a-4ae6-822c-2feb3ad162ab'],
#   ['ripencc',
#    'FR',
#    'ipv4',
#    '5.144.136.0',
#    '2048',
#    '20120711',
#    'allocated',
#    '96a62f03-f912-44d1-b44d-130fc795debe'],
#   ['ripencc',
#    'ES',
#    'ipv4',
#    '5.144.144.0',
#    '2048',
#    '20120712',
#    'allocated',
#    'fbd8518b-fb5d-4534-b99f-b2f1760a3815'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.144.152.0',
#    '256',
#    '20120712',
#    'allocated',
#    'a322e383-57f7-44e6-bcf5-2c0d8b2a83cb'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.144.153.0',
#    '256',
#    '20120712',
#    'allocated',
#    '83e6c399-ba46-402b-a611-8182fc0b87d6'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.144.154.0',
#    '512',
#    '20120712',
#    'allocated',
#    '83e6c399-ba46-402b-a611-8182fc0b87d6'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.144.156.0',
#    '1024',
#    '20120712',
#    'allocated',
#    '8e9520dd-4369-43d5-a02e-3dbcb2435249'],
#   ['ripencc',
#    'IT',
#    'ipv4',
#    '5.144.160.0',
#    '4096',
#    '20120712',
#    'allocated',
#    '27cb5409-3393-4b41-a793-2997c7d3738b'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.144.176.0',
#    '2048',
#    '20120712',
#    'allocated',
#    'cf27f880-cba4-417a-9c80-ed1deaf55bb9'],
#   ['ripencc',
#    'IT',
#    'ipv4',
#    '5.144.184.0',
#    '2048',
#    '20120712',
#    'allocated',
#    '970517a2-ccc4-41e8-917d-5dc432c8a762'],
#   ['ripencc',
#    'GR',
#    'ipv4',
#    '5.144.192.0',
#    '16384',
#    '20120711',
#    'allocated',
#    '6cef4040-6946-4882-a605-fae027e5cb08'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.145.0.0',
#    '8192',
#    '20120712',
#    'allocated',
#    '767e2426-00e2-4183-a41a-de932a6e69e7'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.145.32.0',
#    '8192',
#    '20120712',
#    'allocated',
#    '3b1c9356-4ce6-417e-bbc6-13966e4e0452'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.145.64.0',
#    '8192',
#    '20120712',
#    'allocated',
#    'd227898e-531f-4c3f-bc2c-7a5efaf9d5f8'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.145.96.0',
#    '2048',
#    '20120712',
#    'allocated',
#    'd227898e-531f-4c3f-bc2c-7a5efaf9d5f8'],
#   ['ripencc',
#    'CZ',
#    'ipv4',
#    '5.145.104.0',
#    '2048',
#    '20120712',
#    'allocated',
#    'ec80cdea-57a9-4117-afb3-b8a4ffd495ca'],
#   ['ripencc',
#    'IR',
#    'ipv4',
#    '5.145.112.0',
#    '2048',
#    '20120713',
#    'allocated',
#    '4e255121-12ab-4ac2-8ce2-cece3af9d490'],
#   ['ripencc',
#    'IT',
#    'ipv4',
#    '5.145.120.0',
#    '2048',
#    '20120713',
#    'allocated',
#    '975b67d8-13b6-4bba-b6f4-9edd86f94a26'],
#   ['ripencc',
#    'DE',
#    'ipv4',
#    '5.145.128.0',
#    '4096',
#    '20120713',
#    'allocated',
#    'f4ef3f7d-e32c-4cf2-aca5-c6020de9ad28'],
#   ['ripencc',
#    'CZ',
#    'ipv4',
#    '5.145.144.0',
#    '2048',
#    '20120713',
#    'allocated',
#    '08cf5e26-449b-449d-93f6-aa3e0ad854dc'],
#   ['ripencc',
#    'NO',
#    'ipv4',
#    '5.145.152.0',
#    '2048',
#    '20120713',
#    'allocated',
#    '672125a5-a15f-4f99-8500-46ff15a4856b'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.145.160.0',
#    '2048',
#    '20120713',
#    'allocated',
#    '00dccb57-155b-4b03-9ca8-5911491f5abb'],
#   ['ripencc',
#    'ES',
#    'ipv4',
#    '5.145.168.0',
#    '2048',
#    '20120713',
#    'allocated',
#    'bf7b3867-8f1f-409f-a307-63e637a54c7c'],
#   ['ripencc',
#    'DE',
#    'ipv4',
#    '5.145.176.0',
#    '512',
#    '20120713',
#    'allocated',
#    '0ea8f538-d4c9-400e-b2b0-3ba79ad272d2'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.145.178.0',
#    '512',
#    '20120713',
#    'allocated',
#    'cf03e7b6-8207-4aaf-8b4b-a4b3e59cf9c7'],
#   ['ripencc',
#    'US',
#    'ipv4',
#    '5.145.180.0',
#    '1024',
#    '20120713',
#    'allocated',
#    'd0ac9542-daf7-4467-bf31-99a435f4c9a3'],
#   ['ripencc',
#    'DE',
#    'ipv4',
#    '5.145.184.0',
#    '2048',
#    '20120713',
#    'allocated',
#    '34531eca-20a1-4bc5-b8f9-454a52c20bba'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.145.192.0',
#    '16384',
#    '20120713',
#    'allocated',
#    '00dccb57-155b-4b03-9ca8-5911491f5abb'],
#   ['ripencc',
#    'DE',
#    'ipv4',
#    '5.146.0.0',
#    '131072',
#    '20120713',
#    'allocated',
#    'fd063598-42b0-4610-bc75-770f26c3de73'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.148.0.0',
#    '32768',
#    '20120713',
#    'allocated',
#    'c93532a3-d1cc-4e12-bf60-0af1fc14cfc8'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.148.128.0',
#    '8192',
#    '20120713',
#    'allocated',
#    'c93532a3-d1cc-4e12-bf60-0af1fc14cfc8'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.148.160.0',
#    '8192',
#    '20120713',
#    'allocated',
#    '55fa23ad-2975-459a-8749-55e8f9cae8f7'],
#   ['ripencc',
#    'HU',
#    'ipv4',
#    '5.148.192.0',
#    '16384',
#    '20120713',
#    'allocated',
#    '61980513-dc51-420e-b2e7-21e1c0f729bd'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.149.0.0',
#    '2048',
#    '20120713',
#    'allocated',
#    '83242c4e-7f84-4656-9527-8a22e7242768'],
#   ['ripencc',
#    'GB',
#    'ipv4',
#    '5.149.8.0',
#    '2048',
#    '20120716',
#    'allocated',
#    '82ee65f2-e0a7-4597-91b7-c6a0321a8351'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.149.16.0',
#    '4096',
#    '20120716',
#    'allocated',
#    'a096394b-81e3-4301-b920-77fcce008f62'],
#   ['ripencc',
#    'CH',
#    'ipv4',
#    '5.149.32.0',
#    '8192',
#    '20120716',
#    'allocated',
#    '9c8bc752-0c26-42cb-998a-30460ef2eadc'],
#   ['ripencc',
#    'BA',
#    'ipv4',
#    '5.149.64.0',
#    '4096',
#    '20120716',
#    'allocated',
#    '66eca3d1-da24-4f32-82f9-9812793b19f9'],
#   ['ripencc',
#    'BA',
#    'ipv4',
#    '5.149.80.0',
#    '2048',
#    '20120716',
#    'allocated',
#    '66eca3d1-da24-4f32-82f9-9812793b19f9'],
#   ['ripencc',
#    'BA',
#    'ipv4',
#    '5.149.88.0',
#    '1024',
#    '20120716',
#    'allocated',
#    '5baeac19-491e-497f-ba44-f7134a637e72'],
#   ['ripencc',
#    'BA',
#    'ipv4',
#    '5.149.92.0',
#    '1024',
#    '20120716',
#    'allocated',
#    '66eca3d1-da24-4f32-82f9-9812793b19f9'],
#   ['ripencc',
#    'IQ',
#    'ipv4',
#    '5.149.96.0',
#    '4096',
#    '20120716',
#    'allocated',
#    'e802c0c9-863d-4948-be18-78417ee5b2ee'],
#   ['ripencc',
#    'LU',
#    'ipv4',
#    '5.149.112.0',
#    '2048',
#    '20120716',
#    'allocated',
#    '05831074-ca24-44ec-a870-6c2715717e4c'],
#   ['ripencc',
#    'UA',
#    'ipv4',
#    '5.149.120.0',
#    '2048',
#    '20120716',
#    'allocated',
#    '2fbc3dbe-25ab-4d52-ad74-8460859c886b'],
#   ['ripencc',
#    'SA',
#    'ipv4',
#    '5.149.128.0',
#    '2048',
#    '20120716',
#    'allocated',
#    'ee634923-8f89-41c9-917a-c6bf2868b9ba'],
#   ['ripencc',
#    'BE',
#    'ipv4',
#    '5.149.136.0',
#    '1024',
#    '20120716',
#    'allocated',
#    '42a5fcd4-e390-4e90-926d-168331cdd8d2'],
#   ['ripencc',
#    'BE',
#    'ipv4',
#    '5.149.140.0',
#    '512',
#    '20120716',
#    'allocated',
#    '42a5fcd4-e390-4e90-926d-168331cdd8d2'],
#   ['ripencc',
#    'BE',
#    'ipv4',
#    '5.149.142.0',
#    '256',
#    '20120716',
#    'allocated',
#    '42a5fcd4-e390-4e90-926d-168331cdd8d2'],
#   ['ripencc',
#    'BE',
#    'ipv4',
#    '5.149.143.0',
#    '256',
#    '20120716',
#    'allocated',
#    '32c30a62-f38d-4739-aa5a-5dd44bebc22c'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.149.144.0',
#    '2048',
#    '20120717',
#    'allocated',
#    '142e00e5-f7ac-46c6-9ff8-4795d7f08b10'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.149.152.0',
#    '512',
#    '20120717',
#    'allocated',
#    '55766bb2-eddd-430c-b569-506a2019d2ec'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.149.154.0',
#    '256',
#    '20120717',
#    'allocated',
#    '55766bb2-eddd-430c-b569-506a2019d2ec'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.149.155.0',
#    '256',
#    '20120717',
#    'allocated',
#    '9bf69b84-4418-4441-8229-fc981f415fe0'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.149.156.0',
#    '512',
#    '20120717',
#    'allocated',
#    '9bf69b84-4418-4441-8229-fc981f415fe0'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.149.158.0',
#    '256',
#    '20120717',
#    'allocated',
#    '9bf69b84-4418-4441-8229-fc981f415fe0'],
#   ['ripencc',
#    'RU',
#    'ipv4',
#    '5.149.159.0',
#    '256',
#    '20120717',
#    'allocated',
#    '55766bb2-eddd-430c-b569-506a2019d2ec'],
#   ...]}
